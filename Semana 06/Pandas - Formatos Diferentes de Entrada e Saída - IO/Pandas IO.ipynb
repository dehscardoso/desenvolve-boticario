# %% [markdown]
# <img src = "https://images2.imgbox.com/32/ac/wucGkuem_o.png" width="300">

# %% [markdown]
# # Pandas IO
# ---

# %%
import pandas as pd

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m")

# %%
nomes_m
# Out:
#          nome  regiao     freq  rank sexo
# 0        JOSE       0  5732508     1    M
# 1        JOAO       0  2971935     2    M
# 2     ANTONIO       0  2567494     3    M
# 3   FRANCISCO       0  1765197     4    M
# 4      CARLOS       0  1483121     5    M
# 5       PAULO       0  1417907     6    M
# 6       PEDRO       0  1213557     7    M
# 7       LUCAS       0  1116818     8    M
# 8        LUIZ       0  1102927     9    M
# 9      MARCOS       0  1101126    10    M
# 10       LUIS       0   931530    11    M
# 11    GABRIEL       0   922744    12    M
# 12     RAFAEL       0   814709    13    M
# 13     DANIEL       0   706527    14    M
# 14    MARCELO       0   690098    15    M
# 15      BRUNO       0   663271    16    M
# 16    EDUARDO       0   628539    17    M
# 17     FELIPE       0   615924    18    M
# 18   RAIMUNDO       0   611174    19    M
# 19    RODRIGO       0   598825    20    M

# %%
nomes_f
# Out:
#          nome  regiao      freq  rank sexo
# 0       MARIA       0  11694738     1    F
# 1         ANA       0   3079729     2    F
# 2   FRANCISCA       0    721637     3    F
# 3     ANTONIA       0    588783     4    F
# 4     ADRIANA       0    565621     5    F
# 5     JULIANA       0    562589     6    F
# 6      MARCIA       0    551855     7    F
# 7    FERNANDA       0    531607     8    F
# 8    PATRICIA       0    529446     9    F
# 9       ALINE       0    509869    10    F
# 10     SANDRA       0    479230    11    F
# 11     CAMILA       0    469851    12    F
# 12     AMANDA       0    464624    13    F
# 13      BRUNA       0    460770    14    F
# 14    JESSICA       0    456472    15    F
# 15    LETICIA       0    434056    16    F
# 16      JULIA       0    430067    17    F
# 17    LUCIANA       0    429769    18    F
# 18    VANESSA       0    417512    19    F
# 19    MARIANA       0    381778    20    F

# %%
print("Quantidade de nomes: " + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 40

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame().reset_index(drop=True)

# %%
nomes
# Out:
#          nome
# 0       MARIA
# 1         ANA
# 2   FRANCISCA
# 3     ANTONIA
# 4     ADRIANA
# 5     JULIANA
# 6      MARCIA
# 7    FERNANDA
# 8    PATRICIA
# 9       ALINE
# 10     SANDRA
# 11     CAMILA
# 12     AMANDA
# 13      BRUNA
# 14    JESSICA
# 15    LETICIA
# 16      JULIA
# 17    LUCIANA
# 18    VANESSA
# 19    MARIANA
# 20       JOSE
# 21       JOAO
# 22    ANTONIO
# 23  FRANCISCO
# 24     CARLOS
# 25      PAULO
# 26      PEDRO
# 27      LUCAS
# 28       LUIZ
# 29     MARCOS
# 30       LUIS
# 31    GABRIEL
# 32     RAFAEL
# 33     DANIEL
# 34    MARCELO
# 35      BRUNO
# 36    EDUARDO
# 37     FELIPE
# 38   RAIMUNDO
# 39    RODRIGO

# %%
nomes.sample(5)
# Out:
#          nome
# 23  FRANCISCO
# 12     AMANDA
# 5     JULIANA
# 6      MARCIA
# 21       JOAO

# %% [markdown]
# ## Criando os nomes

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 40

# %%
nomes.sample(3)
# Out:
#       nome
# 6   MARCIA
# 10  SANDRA
# 12  AMANDA

# %% [markdown]
# ## Incluindo ID dos alunos

# %%
nomes["id_aluno"] =  np.random.permutation(total_alunos) + 1

# %%
nomes
# Out:
#          nome  id_aluno
# 0       MARIA         9
# 1         ANA        36
# 2   FRANCISCA        21
# 3     ANTONIA        32
# 4     ADRIANA        29
# 5     JULIANA        30
# 6      MARCIA        10
# 7    FERNANDA        38
# 8    PATRICIA        33
# 9       ALINE         2
# 10     SANDRA        25
# 11     CAMILA        18
# 12     AMANDA        40
# 13      BRUNA         8
# 14    JESSICA        24
# 15    LETICIA        15
# 16      JULIA        20
# 17    LUCIANA        17
# 18    VANESSA        26
# 19    MARIANA         7
# 20       JOSE        37
# 21       JOAO        39
# 22    ANTONIO        16
# 23  FRANCISCO         5
# 24     CARLOS        19
# 25      PAULO        14
# 26      PEDRO        23
# 27      LUCAS        11
# 28       LUIZ        27
# 29     MARCOS         3
# 30       LUIS        12
# 31    GABRIEL         1
# 32     RAFAEL         6
# 33     DANIEL         4
# 34    MARCELO        13
# 35      BRUNO        34
# 36    EDUARDO        35
# 37     FELIPE        28
# 38   RAIMUNDO        31
# 39    RODRIGO        22

# %% [markdown]
# ## Criando os domínios e e-mails

# %%
dominios = ['@grupoboticario.com.br', '@boticario.com']

# %%
dominios = ['@grupoboticario.com.br', '@boticario.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes
# Out:
#          nome  id_aluno                 dominio  \
# 0       MARIA         9  @grupoboticario.com.br
# 1         ANA        36          @boticario.com
# 2   FRANCISCA        21          @boticario.com
# 3     ANTONIA        32          @boticario.com
# 4     ADRIANA        29  @grupoboticario.com.br
# 5     JULIANA        30          @boticario.com
# 6      MARCIA        10          @boticario.com
# 7    FERNANDA        38  @grupoboticario.com.br
# 8    PATRICIA        33  @grupoboticario.com.br
# 9       ALINE         2          @boticario.com
# 10     SANDRA        25          @boticario.com
# 11     CAMILA        18  @grupoboticario.com.br
# 12     AMANDA        40          @boticario.com
# 13      BRUNA         8          @boticario.com
# 14    JESSICA        24          @boticario.com
# 15    LETICIA        15          @boticario.com
# 16      JULIA        20          @boticario.com
# 17    LUCIANA        17          @boticario.com
# 18    VANESSA        26          @boticario.com
# 19    MARIANA         7  @grupoboticario.com.br
# 20       JOSE        37          @boticario.com
# 21       JOAO        39          @boticario.com
# 22    ANTONIO        16          @boticario.com
# 23  FRANCISCO         5          @boticario.com
# 24     CARLOS        19  @grupoboticario.com.br
# 25      PAULO        14  @grupoboticario.com.br
# 26      PEDRO        23  @grupoboticario.com.br
# 27      LUCAS        11          @boticario.com
# 28       LUIZ        27          @boticario.com
# 29     MARCOS         3  @grupoboticario.com.br
# 30       LUIS        12  @grupoboticario.com.br
# 31    GABRIEL         1          @boticario.com
# 32     RAFAEL         6          @boticario.com
# 33     DANIEL         4  @grupoboticario.com.br
# 34    MARCELO        13  @grupoboticario.com.br
# 35      BRUNO        34  @grupoboticario.com.br
# 36    EDUARDO        35          @boticario.com
# 37     FELIPE        28  @grupoboticario.com.br
# 38   RAIMUNDO        31          @boticario.com
# 39    RODRIGO        22          @boticario.com
#
#                              email
# 0      maria@grupoboticario.com.br
# 1                ana@boticario.com
# 2          francisca@boticario.com
# 3            antonia@boticario.com
# 4    adriana@grupoboticario.com.br
# 5            juliana@boticario.com
# 6             marcia@boticario.com
# 7   fernanda@grupoboticario.com.br
# 8   patricia@grupoboticario.com.br
# 9              aline@boticario.com
# 10            sandra@boticario.com
# 11    camila@grupoboticario.com.br
# 12            amanda@boticario.com
# 13             bruna@boticario.com
# 14           jessica@boticario.com
# 15           leticia@boticario.com
# 16             julia@boticario.com
# 17           luciana@boticario.com
# 18           vanessa@boticario.com
# 19   mariana@grupoboticario.com.br
# 20              jose@boticario.com
# 21              joao@boticario.com
# 22           antonio@boticario.com
# 23         francisco@boticario.com
# 24    carlos@grupoboticario.com.br
# 25     paulo@grupoboticario.com.br
# 26     pedro@grupoboticario.com.br
# 27             lucas@boticario.com
# 28              luiz@boticario.com
# 29    marcos@grupoboticario.com.br
# 30      luis@grupoboticario.com.br
# 31           gabriel@boticario.com
# 32            rafael@boticario.com
# 33    daniel@grupoboticario.com.br
# 34   marcelo@grupoboticario.com.br
# 35     bruno@grupoboticario.com.br
# 36           eduardo@boticario.com
# 37    felipe@grupoboticario.com.br
# 38          raimundo@boticario.com
# 39           rodrigo@boticario.com

# %% [markdown]
# ## Criando a tabela de cursos

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %% [markdown]
# ## Alterando o index de cursos

# %%
cursos = cursos.rename(columns={'Nome do curso': 'nome_do_curso'})
cursos.head(2)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web

# %%
cursos['id'] = cursos.index + 1
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# ## Matriculando os alunos nos cursos

# %%
nomes['matriculas'] = np.random.exponential(size=total_alunos).astype(int)
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                          email  \
# 31  GABRIEL         1          @boticario.com          gabriel@boticario.com
# 4   ADRIANA        29  @grupoboticario.com.br  adriana@grupoboticario.com.br
# 0     MARIA         9  @grupoboticario.com.br    maria@grupoboticario.com.br
# 28     LUIZ        27          @boticario.com             luiz@boticario.com
# 12   AMANDA        40          @boticario.com           amanda@boticario.com
#
#     matriculas
# 31           0
# 4            0
# 0            2
# 28           0
# 12           0

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos)).astype(int)
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 39  RODRIGO        22          @boticario.com         rodrigo@boticario.com
# 31  GABRIEL         1          @boticario.com         gabriel@boticario.com
# 13    BRUNA         8          @boticario.com           bruna@boticario.com
# 22  ANTONIO        16          @boticario.com         antonio@boticario.com
# 29   MARCOS         3  @grupoboticario.com.br  marcos@grupoboticario.com.br
#
#     matriculas
# 39           1
# 31           2
# 13           1
# 22           2
# 29           2

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio                        email  \
# 2   FRANCISCA        21          @boticario.com      francisca@boticario.com
# 28       LUIZ        27          @boticario.com           luiz@boticario.com
# 9       ALINE         2          @boticario.com          aline@boticario.com
# 22    ANTONIO        16          @boticario.com        antonio@boticario.com
# 25      PAULO        14  @grupoboticario.com.br  paulo@grupoboticario.com.br
#
#     matriculas
# 2            1
# 28           1
# 9            2
# 22           1
# 25           1

# %%
nomes.matriculas.describe()
# Out:
# count    40.000000
# mean      1.675000
# std       0.997111
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       6.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.histplot(nomes.matriculas, kde=True)
# Out:
# <AxesSubplot:xlabel='matriculas', ylabel='Count'>

# %%
nomes.matriculas.value_counts()
# Out:
# 1    22
# 2    12
# 3     5
# 6     1
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                          email  \
# 4   ADRIANA        29  @grupoboticario.com.br  adriana@grupoboticario.com.br
# 33   DANIEL         4  @grupoboticario.com.br   daniel@grupoboticario.com.br
# 39  RODRIGO        22          @boticario.com          rodrigo@boticario.com
# 14  JESSICA        24          @boticario.com          jessica@boticario.com
# 11   CAMILA        18  @grupoboticario.com.br   camila@grupoboticario.com.br
#
#     matriculas
# 4            1
# 33           3
# 39           1
# 14           1
# 11           2

# %% [markdown]
# ## Selecionando cursos

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
    id = row.id_aluno
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])
matriculas.head(5)
# Out:
#    id_aluno  id_curso
# 0         9        12
# 1         9        20
# 2         9        12
# 3         9         2
# 4         9        12

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso'])
# Out:
#           id_aluno                nome_do_curso
# id_curso
# 1                1        Lógica de programação
# 2                6                Java para Web
# 3                5                  C# para Web
# 4                2                Ruby on Rails
# 5                1             Cursos de Python
# 6                1                PHP com MySql
# 8                6   Novas integrações com Java
# 9                1                 TDD com Java
# 10               6          Código limpo com C#
# 12              13              Hardware básico
# 13               6        Persistência com .NET
# 14               3          Desenvolvendo jogos
# 15               1             Análise de dados
# 16               7           Estatística básica
# 17               1          Internet das coisas
# 18               2        Programação funcional
# 19               3        Boas práticas em Java
# 20               2  Orientação objetos com Java

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                nome_do_curso
# id_curso
# 1                            1        Lógica de programação
# 2                            6                Java para Web
# 3                            5                  C# para Web
# 4                            2                Ruby on Rails
# 5                            1             Cursos de Python
# 6                            1                PHP com MySql
# 8                            6   Novas integrações com Java
# 9                            1                 TDD com Java
# 10                           6          Código limpo com C#
# 12                          13              Hardware básico
# 13                           6        Persistência com .NET
# 14                           3          Desenvolvendo jogos
# 15                           1             Análise de dados
# 16                           7           Estatística básica
# 17                           1          Internet das coisas
# 18                           2        Programação funcional
# 19                           3        Boas práticas em Java
# 20                           2  Orientação objetos com Java

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 37   FELIPE        28  @grupoboticario.com.br  felipe@grupoboticario.com.br
# 28     LUIZ        27          @boticario.com            luiz@boticario.com
# 15  LETICIA        15          @boticario.com         leticia@boticario.com
#
#     matriculas
# 37           2
# 28           1
# 15           2

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0         9        12
# 1         9        20
# 2         9        12
# 3         9         2
# 4         9        12

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            1  Lógica de programação
# 2                            6          Java para Web
# 3                            5            C# para Web
# 4                            2          Ruby on Rails
# 5                            1       Cursos de Python

# %% [markdown]
# ## Saída em diferentes formatos

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index=False)

# %%
pd.read_csv('matriculas_por_curso.csv')
# Out:
#     quantidade_de_alunos                nome_do_curso
# 0                      1        Lógica de programação
# 1                      6                Java para Web
# 2                      5                  C# para Web
# 3                      2                Ruby on Rails
# 4                      1             Cursos de Python
# 5                      1                PHP com MySql
# 6                      6   Novas integrações com Java
# 7                      1                 TDD com Java
# 8                      6          Código limpo com C#
# 9                     13              Hardware básico
# 10                     6        Persistência com .NET
# 11                     3          Desenvolvendo jogos
# 12                     1             Análise de dados
# 13                     7           Estatística básica
# 14                     1          Internet das coisas
# 15                     2        Programação funcional
# 16                     3        Boas práticas em Java
# 17                     2  Orientação objetos com Java

# %%
matriculas_json = matriculas_por_curso.to_json()
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":1,"2":6,"3":5,"4":2,"5":1,"6":1,"8":6,"9":1,"10":6,"12":13,"13":6,"14":3,"15":1,"16":7,"17":1,"18":2,"19":3,"20":2},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","16":"Estat\\u00edstica b\\u00e1sica","17":"Internet das coisas","18":"Programa\\u00e7\\u00e3o funcional","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()
matriculas_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>quantidade_de_alunos</th>\n      <th>nome_do_curso</th>\n    </tr>\n    <tr>\n      <th>id_curso</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Lógica de programação</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>6</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>5</td>\n      <td>C# para Web</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>2</td>\n      <td>Ruby on Rails</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>1</td>\n      <td>Cursos de Python</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>1</td>\n      <td>PHP com MySql</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>6</td>\n      <td>Novas integrações com Java</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>1</td>\n      <td>TDD com Java</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>6</td>\n      <td>Código limpo com C#</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>13</td>\n      <td>Hardware básico</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>6</td>\n      <td>Persistência com .NET</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>3</td>\n      <td>Desenvolvendo jogos</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>1</td>\n      <td>Análise de dados</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>7</td>\n      <td>Estatística básica</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>1</td>\n      <td>Internet das coisas</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>2</td>\n      <td>Programação funcional</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>3</td>\n      <td>Boas práticas em Java</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>2</td>\n      <td>Orientação objetos com Java</td>\n    </tr>\n  </tbody>\n</table>'

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>6</td>
#       <td>Novas integrações com Java</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>TDD com Java</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>6</td>
#       <td>Código limpo com C#</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Hardware básico</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>6</td>
#       <td>Persistência com .NET</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>3</td>
#       <td>Desenvolvendo jogos</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1</td>
#       <td>Análise de dados</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>7</td>
#       <td>Estatística básica</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1</td>
#       <td>Internet das coisas</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2</td>
#       <td>Programação funcional</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>3</td>
#       <td>Boas práticas em Java</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2</td>
#       <td>Orientação objetos com Java</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Criando banco SQL

# %%
# !pip3 install sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect # adicionando o método inspect

engine = create_engine('sqlite:///:memory:')
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)

# %%
inspector = inspect(engine) # criando um Inspector object
print(inspector.get_table_names()) # Exibindo as tabelas com o inspecto
# Out:
# ['matriculas']

# %%
query = 'select * from matriculas where quantidade_de_alunos < 5'

# %%
pd.read_sql(query, engine)
# Out:
#     id_curso  quantidade_de_alunos                nome_do_curso
# 0          1                     1        Lógica de programação
# 1          4                     2                Ruby on Rails
# 2          5                     1             Cursos de Python
# 3          6                     1                PHP com MySql
# 4          9                     1                 TDD com Java
# 5         14                     3          Desenvolvendo jogos
# 6         15                     1             Análise de dados
# 7         17                     1          Internet das coisas
# 8         18                     2        Programação funcional
# 9         19                     3        Boas práticas em Java
# 10        20                     2  Orientação objetos com Java

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                   nome_do_curso  quantidade_de_alunos
# 0         Lógica de programação                     1
# 1                 Java para Web                     6
# 2                   C# para Web                     5
# 3                 Ruby on Rails                     2
# 4              Cursos de Python                     1
# 5                 PHP com MySql                     1
# 6    Novas integrações com Java                     6
# 7                  TDD com Java                     1
# 8           Código limpo com C#                     6
# 9               Hardware básico                    13
# 10        Persistência com .NET                     6
# 11          Desenvolvendo jogos                     3
# 12             Análise de dados                     1
# 13           Estatística básica                     7
# 14          Internet das coisas                     1
# 15        Programação funcional                     2
# 16        Boas práticas em Java                     3
# 17  Orientação objetos com Java                     2

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas.query('quantidade_de_alunos > 2')
# Out:
#                  nome_do_curso  quantidade_de_alunos
# 1                Java para Web                     6
# 2                  C# para Web                     5
# 6   Novas integrações com Java                     6
# 8          Código limpo com C#                     6
# 9              Hardware básico                    13
# 10       Persistência com .NET                     6
# 11         Desenvolvendo jogos                     3
# 13          Estatística básica                     7
# 16       Boas práticas em Java                     3

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 5')
muitas_matriculas
# Out:
#                  nome_do_curso  quantidade_de_alunos
# 1                Java para Web                     6
# 6   Novas integrações com Java                     6
# 8          Código limpo com C#                     6
# 9              Hardware básico                    13
# 10       Persistência com .NET                     6
# 13          Estatística básica                     7

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['matriculas', 'muitas_matriculas']

# %% [markdown]
# ## Escrevendo e lendo excel

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            1  Lógica de programação
# 2                            6          Java para Web
# 3                            5            C# para Web
# 4                            2          Ruby on Rails
# 5                            1       Cursos de Python

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0         9        12
# 1         9        20
# 2         9        12
# 3         9         2
# 4         9        12

# %%
id_curso = 16
proxima_turma = matriculas.query("id_curso == {}".format(id_curso))

# %%
proxima_turma
# Out:
#      id_aluno  id_curso
# 23         18        16
# 27          8        16
# 29         15        16
# 34         17        16
# 35         26        16
# 42         16        16
# 52         12        16
# 104         7        16
# 117         3        16
# 124         4        16
# 128        34        16
# 129        35        16

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso     nome                 dominio  \
# id_aluno
# 18              16   CAMILA  @grupoboticario.com.br
# 8               16    BRUNA          @boticario.com
# 15              16  LETICIA          @boticario.com
# 17              16  LUCIANA          @boticario.com
# 26              16  VANESSA          @boticario.com
# 16              16  ANTONIO          @boticario.com
# 12              16     LUIS  @grupoboticario.com.br
# 7               16  MARIANA  @grupoboticario.com.br
# 3               16   MARCOS  @grupoboticario.com.br
# 4               16   DANIEL  @grupoboticario.com.br
# 34              16    BRUNO  @grupoboticario.com.br
# 35              16  EDUARDO          @boticario.com
#
#                                   email  matriculas
# id_aluno
# 18         camila@grupoboticario.com.br           2
# 8                   bruna@boticario.com           2
# 15                leticia@boticario.com           2
# 17                luciana@boticario.com           2
# 26                vanessa@boticario.com           1
# 16                antonio@boticario.com           1
# 12           luis@grupoboticario.com.br           2
# 7         mariana@grupoboticario.com.br           2
# 3          marcos@grupoboticario.com.br           3
# 4          daniel@grupoboticario.com.br           3
# 34          bruno@grupoboticario.com.br           1
# 35                eduardo@boticario.com           1

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# nome_do_curso    Estatística básica
# Name: 16, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Estatística básica'

# %%
proxima_turma.rename(columns = {'nome':'Alunos do curso de {}'.format(nome_curso)})
# Out:
#          Alunos do curso de Estatística básica
# id_aluno
# 18                                      CAMILA
# 8                                        BRUNA
# 15                                     LETICIA
# 17                                     LUCIANA
# 26                                     VANESSA
# 16                                     ANTONIO
# 12                                        LUIS
# 7                                      MARIANA
# 3                                       MARCOS
# 4                                       DANIEL
# 34                                       BRUNO
# 35                                     EDUARDO

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index = False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#    Alunos do curso de Estatística básica
# 0                                 CAMILA
# 1                                  BRUNA
# 2                                LETICIA
# 3                                LUCIANA
# 4                                VANESSA
# 5                                ANTONIO
# 6                                   LUIS
# 7                                MARIANA
# 8                                 MARCOS
# 9                                 DANIEL
# 10                                 BRUNO
# 11                               EDUARDO
